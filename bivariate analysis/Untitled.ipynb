# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('samsung_mobile_new_data.csv')

# %%
df.sample(10)
# Out:
#                                               name  ratings    price  \
# 174          SAMSUNG Galaxy A03 Core (Blue, 32 GB)      4.1   ₹8,150
# 457       SAMSUNG Galaxy F62 (Laser Green, 128 GB)      4.2  ₹23,999
# 54   SAMSUNG Galaxy S20 FE 5G (Cloud Navy, 128 GB)      4.2  ₹27,440
# 345               SAMSUNG Galaxy A50 (Blue, 64 GB)      3.3  ₹18,600
# 150                         SAMSUNG GT-E1215ZDAINS      4.2   ₹1,299
# 483                         SAMSUNG SM-B310EZDDINS      4.2   ₹2,149
# 504     SAMSUNG Galaxy A52 (Awesome Black, 128 GB)      4.3  ₹31,999
# 21         SAMSUNG Galaxy M13 (Aqua Green, 128 GB)      4.2  ₹13,999
# 288     SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)      4.2  ₹17,989
# 410          OPPO Reno10 5G (Silvery Grey, 256 GB)      4.2  ₹32,999
#
#                                                 imgURL  \
# 174  https://rukminim2.flixcart.com/image/312/312/k...
# 457  https://rukminim2.flixcart.com/image/312/312/k...
# ...

# %%
df2=pd.read_csv('sports_betting_predictive_analysis.csv')

# %%
df2.sample(5)
# Out:
#      Match_ID        Date     Sport                 Home_Team  \
# 446    M00447  2025-06-08  Football      South Shelley Eagles
# 1188   M01189  2025-03-26  Football  New Sylviachester Eagles
# 1143   M01144  2023-11-09  Football      West Sarafort Wolves
# 1200   M01201  2023-12-04  Football         Port Eugene Lions
# 25     M00026  2024-05-04  Football             Dayside Lions
#
#                    Away_Team  Home_Team_Odds  Away_Team_Odds  Draw_Odds  \
# 446        Martintown Tigers            2.57            3.16        NaN
# 1188        East David Bears            2.93            4.76        NaN
# 1143  South Tammyfurt Wolves            4.08            3.11        NaN
# 1200        Davisshire Lions            4.10            4.31        NaN
# 25       South Andrea Eagles            1.29            2.01       2.54
#
#               Predicted_Winner             Actual_Winner
# 446       South Shelley Eagles      South Shelley Eagles
# ...

# %%
df3=pd.read_csv('samsungMobilesData.csv')

# %%
df3.sample(5)
# Out:
#                                               name  ratings  price  \
# 393          SAMSUNG Galaxy J7 Prime (Gold, 32 GB)      4.3  15300
# 204     SAMSUNG Galaxy M14 5G (ICY Silver, 128 GB)      4.2  14885
# 93   SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)      4.5   9463
# 57       SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.2  14499
# 278    SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)      4.3  31999
#
#                                                 imgURL  camera      display  \
# 393  https://rukminim2.flixcart.com/image/312/312/j...      13  other_types
# 204  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 93   https://rukminim2.flixcart.com/image/312/312/x...      50   HD+ AMOLED
# 57   https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 278  https://rukminim2.flixcart.com/image/312/312/k...      64   HD+ AMOLED
#
#      battery  storage  ram                processor  android_version
# ...

# %%
sns.scatterplot(x=df3['camera'], y=df3['price'],size=df3['android_version'])
# Out:
# <Axes: xlabel='camera', ylabel='price'>

# %%
mask=df2['Sport']=='Football'
sport=df2[mask]
sport['Home_Won'] = sport['Home_Team'] == sport['Actual_Winner']
sport['Home_Won2'] = sport['Home_Team'] == sport['Predicted_Winner']
sns.scatterplot(x=sport['Home_Team_Odds'], y=sport['Away_Team_Odds'],hue=sport['Home_Won'],style=sport['Home_Won2'])
# Out:
# <Axes: xlabel='Home_Team_Odds', ylabel='Away_Team_Odds'>

# %%
# Out:
# Home_Team
# Josephchester Lions    1
# dtype: int64

# %%
zom=pd.read_csv('enhanced_zomato_dataset_clean.csv')

# %%
zom
# Out:
#               Restaurant_Name  Dining_Rating  Delivery_Rating  Dining_Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
sns.histplot(data=zom, x='Avg_Price_Cuisine', kde=True)
# Out:
# <Axes: xlabel='Avg_Price_Cuisine', ylabel='Count'>

# %%
sns.pairplot(zom)

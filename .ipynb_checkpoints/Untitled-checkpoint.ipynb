# %% [markdown]
# # 1.Import Dataset

# %%
import pandas as pd

# %%
df2 = pd.read_csv("Diseases_Symptoms.csv",usecols=['Name','Symptoms','Treatments'])

df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df2 = pd.read_csv("Diseases_Symptoms.csv", header=3,usecols=['Name','Symptoms','Treatments'])
#       3 df2
#
# ...

# %%
# Out:
#                                                   Name  \
# 0                              Gestational Cholestasis
# 1                             Injury to Internal Organ
# 2                                              Scabies
# 3                                  Congenital Glaucoma
# 4    Avoidant/Restrictive Food Intake Disorder (ARFID)
# ..                                                 ...
# 400                                       Liver Cancer
# 401                                          Chalazion
# 402                                       Hypocalcemia
# 403                                        Viral Warts
# 404                                        Spondylitis
#
#                                               Symptoms  \
# 0       Itchy skin, particularly on the hands and feet
# 1          Abdominal pain, bleeding, organ dysfunction
# 2    Intense itching, especially at night, small bl...
# 3    Cloudy or hazy eyes, excessive tearing, sensit...
# ...
